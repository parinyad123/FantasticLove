# %%
from timeit import repeat
import numpy as np
from pandas import Interval
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter

# %% [markdown]
# ### Part 1

# %%
from timeit import repeat
import numpy as np
from pandas import Interval
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter 
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 2
    c = -1
    d = 0
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z0 = [0,1]
# number of time points
n = 10000
# time point
t = np.linspace(0,100,n)
# store solution
m = np.empty_like(t)
w = np.empty_like(t)
# record initial conditions
m[0] = z0[0]
w[0] = z0[1]

# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z = odeint(model,z0, tspan)

    m[i] = z[1][0]
    w[i] = z[1][1]
    # print(m[i], w[i])

    z0 = z[1]

# print(len(m))
# print(len(w))
# xlim1 = -1.2
# xlim2 = 1.2
# ylim1 = -1.7
# ylim2 =1.7
fig, ax = plt.subplots()
# ax.set_xlim(xlim1, xlim2)
# ax.set_ylim(ylim1, ylim2)
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part1')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
l = plt.plot(m,w)

redDot, = plt.plot([m[0]], [w[0]], 'ro')

def animate(i):
    # print(i)

    redDot.set_data(m[i], w[i])
    return redDot,

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=10,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 2.1

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 2
    c = -1
    d = -3
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 10000
# time point
t = np.linspace(0,100,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part2-1')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=10,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 2-2

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = -1
    d = -2
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 10000
# time point
t = np.linspace(0,100,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part2-2')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=10,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 2-3

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 5
    c = -1
    d = -1
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 10000
# time point
t = np.linspace(0,100,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part2-3')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=10,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 3-1

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = -1
    d = 3
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,1,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part3-1')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 3-2

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 2
    c = -2
    d = 4
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,1,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part3-2')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part3-3

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 6
    c = -6
    d = 1
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,1,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part3-3')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('par3-31.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part3-3.gif', writer='imagemagick', fps=1000)

# %% [markdown]
# ### Part 4-1

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = 1
    d = -3
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,6,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part4-1')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 4-2

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = 1
    d = -2
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,6,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part4-2')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %% [markdown]
# ### Part 4-3

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = 2
    d = -2
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,3,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part4-3')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)

# %%
def model(z, t):

    m = z[0]
    w = z[1]

    a = 0
    b = 1
    c = 2
    d = -2
    dmdt = a*m + b*w
    dwdt = c*m + d*w
    return [dmdt, dwdt]

# initial condition
z01 = [0,1]
z02 = [1,0]
# number of time points
n = 1000
# time point
t = np.linspace(0,3,n)
# store solution
m1 = np.empty_like(t)
w1 = np.empty_like(t)
m2 = np.empty_like(t)
w2 = np.empty_like(t)
# record initial conditions
m1[0] = z01[0]
w1[0] = z01[1]
m2[0] = z02[0]
w2[0] = z02[1]
# solve ODE
for i in range(1,n):
    tspan = [t[i-1], t[i]]

    z1 = odeint(model,z01, tspan)
    z2 = odeint(model, z02,tspan)
    m1[i] = z1[1][0]
    w1[i] = z1[1][1]
    m2[i] = z2[1][0]
    w2[i] = z2[1][1]
    # print(m[i], w[i])

    z01 = z1[1]
    z02 = z2[1]

# print(len(m))
# print(len(w))

fig, ax = plt.subplots()
ax.set_ylabel('w(t)')
ax.set_xlabel('m(t)')
ax.set_title('Part4-3')
ax.axhline(color='k', lw=0.8, ls='--')
ax.axvline(color='k', lw=0.8, ls='--')
plt.plot(m1,w1)
plt.plot(m2,w2)

redDot1, = plt.plot([m1[0]], [w1[0]], 'ro')
redDot2, = plt.plot([m2[0]], [w2[0]], 'go')
def animate(i):
    # print(i)

    redDot1.set_data(m1[i], w1[i])
    redDot2.set_data(m2[i], w2[i])
    return redDot1,redDot2

myAnimation = FuncAnimation(fig, animate, frames=range(0,1000),\
            interval=.5,blit=True, repeat=True)
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
plt.show()
# myAnimation.save('part1.gif', writer='imagemagick', fps=200)
